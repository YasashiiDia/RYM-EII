# %% [markdown]
# <a href="https://colab.research.google.com/github/YasashiiDia/RYM-EII/blob/master/EII_Acting_Performances.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##<b>RYM Top Acting Performances Round 1 Results</b>
#
# Full RYM List: <a href="https://rateyourmusic.com/list/novocaine69/eii-ap-rym-picks-the-500-most-extraordinary-iconic-and-influential-acting-performances-in-cinematic-history/">RYM Picks the 500 Most Extraordinary, Iconic & Influential Acting Performances in Cinematic History</a>
#
# This notebook is still a work in progress!
#
# **You need to be signed into your Google account if you want to interact with this notebook.** You also need to accept the prompt warning you that this notebook was not authored by Google. You can review the source code of this notebook by double clicking on any cell titles.
#
# Alternatively, you can also view the full data on <a href="https://docs.google.com/spreadsheets/d/1aDqnSxAtr2jMKpfs6httGwOXAe5bkQPkB0aw7wRzI3Y/edit#gid=2074567097">Google Sheets</a> without a Google account, where you can use custom sorts and filters (Data->Filter views->Create new temporary filter view). It is not quite as convenient and neat as this chart, but you can achieve the similar levels of functionality.

# %%
#@title Instructions
#@markdown First, run all cells with Ctrl+F9 or by selecting *Runtime* -> *Run all* in the menu bar above. This loads the data and activates all interactive widgets below.\
#@markdown If anything breaks, try re-running the corresponding cell (using the run button on the left) or all the cells from the top. Else contact me on RYM (YasashiiDia).

from IPython.display import HTML
import numpy as np
import pandas as pd
import io

pd.set_option('max_rows', None)

csv='''Rank,Points,Votes,Name,Film,Group,Group Rank,Vote Distribution,Year,Place of Birth,Gender,Birthday,Deathday,Age,Release Date,Genres,ID
1,60,17,Daniel Day-Lewis,There Will Be Blood,13,1,43234444343424444,2007,UK,2,1957-04-29,None,50,2007-09-27,Drama,210
2,55,15,Marlon Brando,The Godfather,16,1,334244434444444,1972,USA,2,1924-04-03,2004-07-01,47,1972-03-14,"Drama, Crime",606
3,55,15,Toshiro Mifune,Seven Samurai,4,1,434444434443343,1954,China,2,1920-04-01,1997-12-24,34,1954-04-26,"Action, Drama",942
4,55,14,Al Pacino,Dog Day Afternoon,17,1,44444434444444,1975,USA,2,1940-04-25,None,35,1975-09-19,"Crime, Drama, Thriller",11
5,54,16,Al Pacino,The Godfather Part II,3,1,3442342443432444,1974,USA,2,1940-04-25,None,34,1974-12-20,"Drama, Crime",16
6,54,15,Jack Nicholson,One Flew Over the Cuckoo's Nest,7,1,444443443144443,1975,USA,2,1937-04-22,None,38,1975-11-18,Drama,396
6,54,15,Peter O’Toole,Lawrence of Arabia,14,1,443344442442444,1962,Ireland,2,1932-08-02,2013-12-14,30,1962-12-10,"Adventure, Drama, History, War",714
8,54,15,Philip Seymour Hoffman,The Master,3,2,442334444434344,2012,USA,2,1967-07-23,2014-02-02,45,2012-09-01,Drama,723
9,53,16,Henry Fonda,12 Angry Men,3,3,4344244243422434,1957,USA,2,1905-05-16,1982-08-12,51,1957-04-10,Drama,357
10,53,15,Robert De Niro,Raging Bull,13,3,234444434344442,1980,USA,2,1943-08-17,None,37,1980-11-14,"Drama, Action",752
11,52,15,Gena Rowlands,A Woman Under the Influence,3,4,444343244444314,1974,USA,1,1930-06-19,None,44,1974-09-19,Drama,303
988,1,1,Billie Burke,Topper,2,50,1,1937,USA,1,1884-08-07,1970-05-15,52,1937-07-16,"Comedy, Fantasy, Romance",101
991,0,0,Darya Zhovner,Closeness,17,49,,2017,Russia,1,1992-09-20,None,24,2017-05-09,Drama,927
991,0,0,Martin Balsam,Confessions of a Police Captain,17,49,,1971,USA,2,1919-11-04,1996-02-13,51,1971-03-26,"Crime, Drama",608
991,0,0,Juli Jakab,Sunset,7,50,,2018,Hungary,1,1988-01-01,None,30,2018-09-02,"Mystery, Drama, History",491
991,0,0,Lucian Teodor Rus,Scarred Hearts,11,50,,2016,None,0,None,None,0,2016-08-07,Drama,565
991,0,0,Giacomo Rizzo,The Family Friend,11,49,,2006,Italy,2,1939-01-17,None,67,2006-10-01,Drama,324
991,0,0,Mariana di Girolamo,Ema,19,49,,2019,Chile,1,1990-10-22,None,28,2019-08-31,Drama,585
991,0,0,Massimo Troisi,What Time Is It?,8,50,,1989,Italy,0,1953-02-19,1994-06-04,36,1989-09-27,"Comedy, Drama",614
991,0,0,Meryl Streep,Out of Africa,19,49,,1985,USA,1,1949-06-22,None,36,1985-12-20,"History, Romance, Drama",627
991,0,0,Christopher Walken,The Comfort of Strangers,14,50,,1990,USA,2,1943-03-31,None,46,1990-01-01,"Romance, Drama",182
991,0,0,Queen Latifah,Set It Off,15,50,,1996,USA,1,1970-03-18,None,26,1996-11-06,"Crime, Drama, Thriller",726
991,0,0,Riccardo Cucciolla,Dirty Money,20,51,,1972,Italy,2,1924-09-05,1999-09-17,48,1972-09-30,"Crime, Action, Thriller",737'''

# %%
#@title Interactive Chart

import ipywidgets as widgets
from IPython.display import display

data = io.StringIO(csv)
df = pd.read_csv(data, sep=",", dtype={'Vote Distribution': object,'Place of Birth':'category'})

df.index = df['ID']
df = df.drop(['ID'],axis=1)
df.index.name = None

df = df.drop(['Year'],axis=1)

df['Gender'] = df['Gender'].mask(df['Gender'] == 2, 'm')
df['Gender'] = df['Gender'].mask(df['Gender'] == 1, 'f')
df['Gender'] = df['Gender'].mask(df['Gender'] == 0, '')
df['Gender'] = df['Gender'].astype('category')

df = df.sort_values(by='Rank')

genredf = df['Genres'].str.split(', ').explode()
unique_genres = genredf.groupby(genredf).size().index.values.tolist()

countrydf = df['Place of Birth']
unique_countries = countrydf.groupby(countrydf).size().index.values.tolist()
unique_countries.insert(0,'USA & UK')

def hover(hover_color='silver'):
    return dict(selector="tr:hover", props=[("background-color", "%s" % hover_color)])

def alternate_row_colors(background_color='gainsboro'):
  return dict(selector='tr:nth-child(even)',props=[("background-color", "%s" % background_color)])

def color_code(s, column):
  n = len(s)
  r = s.loc[column].item()
  if r < 4:
    return ['color: purple' for i in range(n)]
  elif (r > 3 and r < 11):
    return ['color: green' for i in range(n)]
  elif (r > 10 and r < 21):
    return ['color: brown' for i in range(n)]
  elif (r > 20 and r < 31):
    return ['color: red' for i in range(n)]
  return ['color: dimgrey' for i in range(n)]

def print_df(df):
  for i in df.index:
    r = df.loc[i,'Group Rank']
    if r < 4:
      color = '[color purple]'
    elif (r > 3 and r < 11):
      color = '[color green]'
    elif (r > 10 and r < 21):
      color = '[color brown]'
    elif (r > 20 and r < 31):
      color = '[color red]'
    else:
      color = '[color dimgrey]'

    print('{}{}. {} in {} ({}) {} [{}/{}][/color]'.format(color, df.loc[i,'Rank'], df.loc[i,'Name'], 
                        df.loc[i,'Film'], df.loc[i,'Release Date'][:4],
                        df.loc[i,'Vote Distribution'], df.loc[i,'Points'], df.loc[i,'Votes']))

def style_df(a):
    a_styled = a.style.set_properties(**{'text-align': 'center'}).hide_index()
    #styles = [alternate_row_colors(),hover()]   
    styles = [hover()] 
    a_styled.set_table_styles(styles)
    a_styled.apply(color_code, column=['Group Rank'], axis=1)
    return a_styled
        
def filt(a, Results, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Sort='', Ascending=True):
    
    a = a [a['Release Date'].str[:4].astype(int) <= Year[1]]
    a = a [a['Release Date'].str[:4].astype(int) >= Year[0]]

    a = a[(a['Group Rank'] <= GroupRank[1]) & (a['Group Rank'] >= GroupRank[0])]
    a = a[(a['Age'] <= Age[1]) & (a['Age'] >= Age[0])]

    if Sort not in ['Group', 'Group Rank', '']:
      a=a.sort_values(by=[Sort],ascending=Ascending)
    elif Sort == 'Group':
      a=a.sort_values(by=['Group','Group Rank'],ascending=Ascending)
    elif Sort == 'Group Rank':
      a=a.sort_values(by=['Group Rank','Group'],ascending=Ascending)

    if ExGenres != '':
        a = a[a['Genres'].str.find(ExGenres) < 0]
        
    if InGenres != '':
        a = a[a['Genres'].str.find(InGenres) > -1]
        #a = a[(a['Genres'].str.find('Horror') > -1) | (a['Genres'].str.find('Science Fiction') > -1) | (a['Genres'].str.find('Fantasy') > -1)]

    if Country != '':
        if (Country.find('&')  > -1):
          Country, Country_2 = Country.split('&')
          a = a[(a['Place of Birth'].str.find(Country_2.strip()) > -1) | (a['Place of Birth'].str.find(Country.strip()) > -1)]
        else:
          a = a[a['Place of Birth'].str.find(Country.strip()) > -1]

    if ExCountry != '':
        if (ExCountry.find('&')  > -1):
          ExCountry, ExCountry_2 = ExCountry.split('&')
          a = a[a['Place of Birth'].str.find(ExCountry_2.strip()) < 0]
        a = a[a['Place of Birth'].str.find(ExCountry.strip()) < 0]

    if Gender == 'Male':
      a = a[a['Gender'] == 'm']
    elif Gender == 'Female':
      a = a[a['Gender'] == 'f']
    #elif Gender == 'Other':
      #a = a[a['Gender'] == '']

    return a[:Results]

def display_df(Results, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Sort, Ascending, Print):

    a = filt(df, Results, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Sort, Ascending)

    if Print:
      print_df(a)

    a_styled = style_df(a)
    print('Entries:', len(a))
    display(a_styled)

# Widgets
max_age = df['Age'].max()

layout={'width': '350px'}

res_w = widgets.IntSlider(min=10, max=1001, step=10,layout=layout,value=30,description='Results:')
year_w = widgets.IntRangeSlider(min=1917, max=2019, step=1,layout=layout,value=[1917,2019],description='Year:')
sort_w = widgets.Dropdown(options=['Rank','Votes','Name','Film','Group','Group Rank','Birthday','Deathday','Release Date','Age'],layout=layout,value='Rank',description='Sort:')
gender_w = widgets.Dropdown(options=['All','Male','Female'],layout=layout,value='All',description='Gender:')
check_w = widgets.Checkbox(value=True,description='Ascending')
print_w = widgets.Checkbox(value=False,description='Forum Print')

group_w = widgets.IntRangeSlider(min=1, max=51, step=1,layout=layout,value=[1,51],description='Gr. Rank:')
age_w = widgets.IntRangeSlider(min=0, max=max_age, step=1,layout=layout,value=[0,max_age],description='Age:')

#exgenres_w_multi = widgets.SelectMultiple(options=unique_genres,value=['Drama'],rows=3,description='Ex. Genre:')
exgenres_w = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Exclude Genre',description='Ex. Genre:')
ingenres_w = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Include Genre',description='In. Genre:')

country_w = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Include Place of Birth',description='In. Country:')
excountry_w = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Exclude Place of Birth',description='Ex. Country:')


ws = [res_w,year_w,group_w,age_w,country_w,excountry_w,ingenres_w,exgenres_w,sort_w,gender_w,check_w, print_w]

args = {'Results','Year','Country','ExCountry','Gender','InGenres','ExGenres','Ascending','Sort','Print','GroupRank','Age'}

out = widgets.interactive_output(display_df,{'Results':res_w,'Year':year_w,'Country':country_w,'ExCountry':excountry_w,'Gender':gender_w,'InGenres':ingenres_w,'ExGenres':exgenres_w,'Ascending':check_w,'Sort':sort_w,'Print':print_w,'GroupRank':group_w,'Age':age_w})
ui = widgets.GridBox(ws, layout=widgets.Layout(grid_template_columns="repeat(2, 400px)"))

display(ui, out)
# Out:
# GridBox(children=(IntSlider(value=30, description='Results:', layout=Layout(width='350px'), max=1001, min=10, …
# Output()

# %%
#@title Pie Charts
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interactive_output
# %matplotlib inline
sns.set()

mpl.rcParams['font.size'] = 20.0
labelfontsize = 14
textprops={'fontsize': 14, 'family':'DejaVu Sans Mono'}
textcolor = 'dimgray'

# Define rectangle in axes coords
left, width = .25, .5
bottom, height = .25, .5
right = left + width
top = bottom + height

bboxprops = dict(boxstyle='round', pad=0.5, alpha=0.8, facecolor='lemonchiffon', edgecolor='darkgoldenrod')

# Slice pie in accetable sizes and put remaining pie in 'Other'
def pie_slicer(series, cm=None, thresh=0.02):
  tot = series.sum()
  other, n_slices = 0, 0
  serieslist = series.tolist()
  labels, sizes = [], []

  for i, s in enumerate(series):
    if s/tot < thresh:
      other += s
    else:
      n_slices += 1
      labels.append(series.index[i])
      sizes.append(s)
  
  if other/tot > thresh:
    labels.append('Other')
    sizes.append(other)

  colors = [plt.get_cmap('Pastel1')(i) for i in range(9)]
  [colors.append(plt.get_cmap('Pastel2')(i)) for i in range(9)]
  if cm:
    colors = [plt.get_cmap(cm)(i) for i in np.linspace(0, 1, n_slices+2)]
  return labels, sizes, colors

def pies(Top, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Weight, Sort, Ascending, Print):

    try:
      a = filt(df, 1001, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Sort, Ascending)    
      a = a[(a['Rank'] <= Top[1]) & (a['Rank'] >= Top[0])]

      fig, (ax1,ax2,ax3) = plt.subplots(1, 3, figsize = (18,6))
      plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.4, hspace=0.6)

      # Country pie
      if Weight == 'None':
        g = a['Place of Birth']
        g = g.groupby(g).size().sort_values(ascending=False)
      else:
        g = a.groupby(['Place of Birth'])[Weight].sum().sort_values(ascending=False)

      labels, sizes, colors = pie_slicer(g)

      patches, texts, autotexts = ax2.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90,textprops=textprops)
      ax2.axis('equal')
      [text.set_color(textcolor) for text in texts]
      [autotext.set_color(textcolor) for autotext in autotexts]

      # Genre pie
      expl = a
      expl['Genres'] = expl['Genres'].str.split(', ')
      expl = expl.explode('Genres')
      if Weight == 'None':
        g = expl['Genres']
        g = g.groupby(g).size().sort_values(ascending=False)
      else:
        g = expl.groupby('Genres')[Weight].sum().sort_values(ascending=False)

      labels, sizes, colors = pie_slicer(g)

      patches, texts, autotexts = ax1.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90,textprops=textprops)
      ax1.axis('equal')
      [text.set_color(textcolor) for text in texts]
      [autotext.set_color(textcolor) for autotext in autotexts]

      # Gender pie
      if Weight == 'None':
        g = a['Gender']
        g = g.groupby(g).size().sort_values(ascending=False)
      else:
        g = a.groupby(['Gender'])[Weight].sum().sort_values(ascending=False)

      labels, sizes, colors = pie_slicer(g)
      if Gender == 'Male':
        labels = ['Male']
      elif Gender == 'Female':
        labels = ['Female']
      else:
        labels = ['Male','Female']
        sizes=sizes[:2]

      patches, texts, autotexts = ax3.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90,textprops=textprops)
      ax3.axis('equal')

      [text.set_color(textcolor) for text in texts]
      [autotext.set_color(textcolor) for autotext in autotexts]

      plt.tight_layout()
      plt.show()

    except ValueError:
      print('\nNo entries match criteria')
      pass

# Widgets
n_titles=len(df)
max_age = df['Age'].max()
layout={'width': '350px'}

top_wp = widgets.IntRangeSlider(min=1, max=n_titles, step=1,value=(1,n_titles),layout=layout,description='Rank:',continuous_update=False)
weight_wp = widgets.Dropdown(options=['None','Points'],layout=layout,value='None',description='Weight:')

year_wp = widgets.IntRangeSlider(min=1917, max=2019, step=1,layout=layout,value=[1917,2019],description='Year:')
sort_wp = widgets.Dropdown(options=['Rank','Release Date','Age','Group','Group Rank'],layout=layout,value='Rank',description='Sort:')
gender_wp = widgets.Dropdown(options=['All','Male','Female'],layout=layout,value='All',description='Gender:')
check_wp = widgets.Checkbox(value=True,description='Ascending')
print_wp = widgets.Checkbox(value=False,description='Forum Print')

group_wp = widgets.IntRangeSlider(min=1, max=51, step=1,layout=layout,value=[1,51],description='Gr. Rank:')
age_wp = widgets.IntRangeSlider(min=0, max=max_age, step=1,layout=layout,value=[0,max_age],description='Age:')

exgenres_wp = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Exclude Genre',description='Ex. Genre:')
ingenres_wp = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Include Genre',description='In. Genre:')

country_wp = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Include Place of Birth',description='In. Country:')
excountry_wp = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Exclude Place of Birth',description='Ex. Country:')


wsp = [top_wp,year_wp,group_wp,age_wp,country_wp,excountry_wp,ingenres_wp,exgenres_wp,gender_wp, weight_wp]

interactive_pies = interactive_output(pies, {'Top':top_wp,'Year':year_wp,'Country':country_wp,'ExCountry':excountry_wp,'Gender':gender_wp,'InGenres':ingenres_wp,'ExGenres':exgenres_wp,'Ascending':check_wp,'Sort':sort_wp,'Print':print_wp,'GroupRank':group_wp,'Age':age_wp,'Weight':weight_wp})
interactive_pies.layout.height = '350px'

ui_pies = widgets.GridBox(wsp, layout=widgets.Layout(grid_template_columns="repeat(2, 400px)"))

display(ui_pies, interactive_pies)
# Out:
# GridBox(children=(IntRangeSlider(value=(1, 1001), continuous_update=False, description='Rank:', layout=Layout(…
# Output(layout=Layout(height='350px'))

# %%
#@title Histograms
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interactive_output
sns.set()

import warnings
warnings.filterwarnings('ignore')

def histos(Top, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Weight, Sort):
    try:
      a = filt(df, 1001, Year, Country, ExCountry, Gender, InGenres, ExGenres, GroupRank, Age, Sort, False)    
      a = a[(a['Rank'] <= Top[1]) & (a['Rank'] >= Top[0])]
  
      fullyeardf = df['Release Date'].str[:4].astype(int)
      yeardf = a['Release Date'].str[:4].astype(int)

      fullyearweights = df['Points'] if Weight != 'None' else np.ones(len(df))
      yearweights = a['Points'] if Weight != 'None' else np.ones(len(a))

      print("\n")
      fig2, (ax21, ax22) = plt.subplots(1,2,figsize = (24,8))

      # Year histogram

      ax21.tick_params(labelsize=20)
      nfull, binsfull, patchesfull = ax21.hist(fullyeardf,range=(1917,2020),bins=103,alpha=0.3,weights=fullyearweights)
      n, bins, patches = ax21.hist(yeardf,range=(1917,2020),bins=103,weights=yearweights,color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725))

      ax21.set_title('Release year',size=22)

      if Weight == 'None':
        topyears = yeardf.groupby(yeardf).count().sort_values(ascending=False).iloc[:10]
        decadedf = 10 * (yeardf // 10)
        decades = decadedf.groupby(decadedf).count()
      else:
        g = a
        g['Year'] = g['Release Date'].str[:4].astype(int)
        g['Decade'] = 10*(g['Year'] // 10)
        topyears = g.groupby('Year')[Weight].sum().sort_values(ascending=False).iloc[:10]
        decades = g.groupby('Decade')[Weight].sum()

      t = ['  '+str(topyears.index.values[i])+':   '+str(topyears.values[i])+'\n' for i in range(len(topyears))]
      text = 'Top 10 Years\n\n'+''.join(t)[:-1]

      t = ['  '+str(decades.index.values[i])+'s:  '+str(decades.values[i])+'\n' for i in range(len(decades))]
      text2 = '  1900s:  0\n'+''.join(t)[:-1]

      props = dict(boxstyle='round', pad=0.5, alpha=0.8, facecolor='plum', edgecolor='indigo')

      ax21.text(0.02, 0.54, text, transform=ax21.transAxes, fontsize=15, bbox=props)
      ax21.text(0.19, 0.54, text2, transform=ax21.transAxes, fontsize=15, bbox=props)

      ax21.set_ylim(0, 1.04*max(nfull))

      # Age histogram

      kwargs = dict(range = (10,90),bins=30,alpha=0.5)
      #kwargs2 = dict(range = (10,90),bins=30,fc=(0, 0, 0, 0),edgecolor='black', linewidth=1.2)
      ax22.tick_params(labelsize=20)

      valid_ages = a[(a['Age']<100) & (a['Age']>0)]
      valid_ages_full = df[(df['Age']<100) & (df['Age']>0)]

      maledf = valid_ages['Age'][valid_ages['Gender']=='m']
      femaledf = valid_ages['Age'][valid_ages['Gender']=='f']

      maleweights = valid_ages[valid_ages['Gender']=='m']['Points'] if Weight != 'None' else None
      femaleweights = valid_ages[valid_ages['Gender']=='f']['Points'] if Weight != 'None' else None

      nm, binsm, patchesm = ax22.hist(maledf,weights=maleweights,label='Male',**kwargs)
      nf, binsf, patchesf = ax22.hist(femaledf,weights=femaleweights,label='Female',**kwargs)
      #nmf, binsmf, patchesmf = ax22.hist(valid_ages_full['Age'][valid_ages_full['Gender']=='m'],label='Male',**kwargs2)
      #nff, binsff, patchesff = ax22.hist(valid_ages_full['Age'][valid_ages_full['Gender']=='f'],label='Female',**kwargs2)
      ax22.set_title('Age at release',size=22)

      ax22.legend(fontsize=20,loc="upper left")
      ax22.set_ylim(0, 1.04*max(max(nm),max(nf)))

      std = np.sqrt(np.cov(valid_ages['Age'].values, aweights=valid_ages['Points'].values))
      mean = np.average(valid_ages['Age'].values,weights=valid_ages['Points'].values)

      male_mean = np.average(maledf.values,weights=maleweights)
      male_std = np.sqrt(np.cov(maledf.values, aweights=maleweights))
      female_mean = np.average(femaledf.values,weights=femaleweights)
      female_std = np.sqrt(np.cov(femaledf.values, aweights=femaleweights))

      mode = valid_ages['Age'].mode().iloc[0]
      male_mode = maledf.mode().iloc[0]
      female_mode = femaledf.mode().iloc[0]

      textstr  = 'Mean:    {:.1f} +/- {:.1f}\n'.format(mean,std)
      textstr += 'Male:     {:.1f} +/- {:.1f}\n'.format(male_mean,male_std)
      textstr += 'Female: {:.1f} +/- {:.1f}'.format(female_mean,female_std)

      textstr2  = 'Mode:    {:.0f}\n'.format(mode)
      textstr2 += 'Male:     {:.0f}\n'.format(male_mode)
      textstr2 += 'Female: {:.0f}'.format(female_mode)

      # these are matplotlib.patch.Patch properties
      props = dict(boxstyle='round', alpha=0.8, facecolor='plum', edgecolor='indigo')

      ax22.text(0.71, 0.97, textstr, transform=ax22.transAxes, fontsize=16,
              verticalalignment='top', bbox=props)

      ax22.text(0.54, 0.97, textstr2, transform=ax22.transAxes, fontsize=16,
              verticalalignment='top', bbox=props)
      
      print('Entries:',len(a))
    except IndexError:
      pass
    except ZeroDivisionError:
      pass

    plt.tight_layout()
    plt.show()

# Widgets
n_titles=len(df)
max_age = df['Age'].max()
layout={'width': '350px'}

top_wh = widgets.IntRangeSlider(min=1, max=n_titles, step=1,value=(1,n_titles),layout=layout,description='Rank:',continuous_update=False)
weight_wh = widgets.Dropdown(options=['None','Points'],layout=layout,value='None',description='Weight:')

year_wh = widgets.IntRangeSlider(min=1917, max=2019, step=1,layout=layout,value=[1917,2019],description='Year:',continuous_update=False)
sort_wh = widgets.Dropdown(options=['Rank','Release Date','Age','Group','Group Rank'],layout=layout,value='Rank',description='Sort:')
gender_wh = widgets.Dropdown(options=['All','Male','Female'],layout=layout,value='All',description='Gender:')

group_wh = widgets.IntRangeSlider(min=1, max=51, step=1,layout=layout,value=[1,51],description='Gr. Rank:',continuous_update=False)
age_wh = widgets.IntRangeSlider(min=0, max=max_age, step=1,layout=layout,value=[0,max_age],description='Age:',continuous_update=False)

exgenres_wh = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Exclude Genre',description='Ex. Genre:',continuous_update=False)
ingenres_wh = widgets.Combobox(layout=layout,options=unique_genres,placeholder='Include Genre',description='In. Genre:',continuous_update=False)

country_wh = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Include Place of Birth',description='In. Country:')
excountry_wh = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Exclude Place of Birth',description='Ex. Country:')

wsh = [top_wh,year_wh,group_wh,age_wh,country_wh,excountry_wh,ingenres_wh,exgenres_wh,gender_wh, weight_wh]

interactive_histos = interactive_output(histos, {'Top':top_wh,'Year':year_wh,'Country':country_wh,'ExCountry':excountry_wh,'Gender':gender_wh,'InGenres':ingenres_wh,'ExGenres':exgenres_wh,'Sort':sort_wh,'GroupRank':group_wh,'Age':age_wh,'Weight':weight_wh})
interactive_histos.layout.height = '350px'

ui_histos = widgets.GridBox(wsh, layout=widgets.Layout(grid_template_columns="repeat(2, 400px)"))

display(ui_histos, interactive_histos)
# Out:
# GridBox(children=(IntRangeSlider(value=(1, 1001), continuous_update=False, description='Rank:', layout=Layout(…
# Output(layout=Layout(height='350px'))

# %%
#@title Top Actors

groups = df.groupby('Name')

actors_counts = groups['Name'].count()
actorsdf = pd.DataFrame(actors_counts.values, index = actors_counts.index, columns=['Films']) 
actorsdf['Points'] = groups.sum()['Points']
actorsdf['Rank']  = actorsdf['Points'].rank(ascending=False,method='min').astype(int)
actorsdf['Votes'] = groups.sum()['Votes']

actorsdf['Gender'] = groups['Name'].count()
actorsdf['Birthday'] = actorsdf['Gender']
actorsdf['Deathday'] = actorsdf['Gender']
actorsdf['Place of Birth'] = actorsdf['Gender']

for actor in actors_counts.index:
  actorsdf.loc[actor,'Gender'] = groups.get_group(actor)['Gender'].iloc[0]
  actorsdf.loc[actor,'Birthday'] = groups.get_group(actor)['Birthday'].iloc[0]
  actorsdf.loc[actor,'Deathday'] = groups.get_group(actor)['Deathday'].iloc[0]
  actorsdf.loc[actor,'Place of Birth'] = groups.get_group(actor)['Place of Birth'].iloc[0]

oldest = df['Birthday'].min()[:4]
youngest = df['Birthday'].mask(df['Birthday'] == 'None','0000').max()[:4]

def print_actorsdf(df):
  for i in df.index:
    if df.loc[i,'Gender'] == 'm':
      color = '[color navy]'
    elif df.loc[i,'Gender'] == 'f':
      color = '[color red]'
    else:
      color = '[color black]'
    print('{}{}. {} [{}/{}/{}][/color]'.format(color,df.loc[i,'Rank'],i,df.loc[i,'Points'],df.loc[i,'Votes'],df.loc[i,'Films']))

def gender_colors(s, column):
  n = len(s)
  r = s.loc[column].item()
  if r == 'm':
    return ['color: navy' for i in range(n)]
  elif (r == 'f'):
    return ['color: red' for i in range(n)]
  return ['color: black' for i in range(n)]

def style_actorsdf(a):
    a['Name'] = a.index
    a = a[['Rank','Name','Points','Votes','Films','Place of Birth','Gender','Birthday','Deathday']]

    a_styled = a.style.set_properties(**{'text-align': 'center'}).hide_index()  
    styles = [hover()] 
    a_styled.set_table_styles(styles)
    a_styled.apply(gender_colors, column=['Gender'], axis=1)
    return a_styled

def actors(Top,Year,Country,ExCountry,Gender,Ascending,Sort,Print):

  a = actorsdf.sort_values(by=Sort,ascending=Ascending)

  a['Birthday'] = a['Birthday'].mask(a['Birthday'] == 'None', '0000')
  a = a[a['Birthday'].str[:4].astype(int) <= Year[1]]
  bottom = Year[0] if Year[0] > int(oldest) else 0
  a = a[a['Birthday'].str[:4].astype(int) >= bottom]
  a['Birthday'] = a['Birthday'].mask(a['Birthday'] == '0000', 'None')

  if Gender == 'Male':
    a = a[a['Gender'] == 'm']
  elif Gender == 'Female':
    a = a[a['Gender'] == 'f']

  if Country != '':
    if (Country.find('&')  > -1):
      Country, Country_2 = Country.split('&')
      a = a[(a['Place of Birth'].str.find(Country_2.strip()) > -1) | (a['Place of Birth'].str.find(Country.strip()) > -1)]
    else:
      a = a[a['Place of Birth'].str.find(Country.strip()) > -1]

  if ExCountry != '':
      if (ExCountry.find('&')  > -1):
        ExCountry, ExCountry_2 = ExCountry.split('&')
        a = a[a['Place of Birth'].str.find(ExCountry_2.strip()) < 0]
      a = a[a['Place of Birth'].str.find(ExCountry.strip()) < 0]

  a = a.head(Top)

  if Print:
    print_actorsdf(a)

  a_styled = style_actorsdf(a)

  print('Entries:', len(a))
  display(a_styled)

# Widgets
n_actors=len(actorsdf)
layout={'width': '350px'}

top_wa = widgets.IntSlider(min=10, max=n_actors, step=10,value=30,layout=layout,description='Results:',continuous_update=False)
year_wa = widgets.IntRangeSlider(min=oldest, max=youngest, step=1,layout=layout,value=[oldest,youngest],description='Birth Year:',continuous_update=False)
sort_wa = widgets.Dropdown(options=['Points','Votes','Films','Name','Place of Birth','Birthday','Deathday'],layout=layout,value='Points',description='Sort:')
gender_wa = widgets.Dropdown(options=['All','Male','Female'],layout=layout,value='All',description='Gender:')
country_wa = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Include Place of Birth',description='In. Country:')
excountry_wa = widgets.Combobox(layout=layout,options=unique_countries,placeholder='Exclude Place of Birth',description='Ex. Country:')
check_wa = widgets.Checkbox(value=False,description='Ascending')
print_wa = widgets.Checkbox(value=False,description='Forum Print')

wsa = [top_wa,year_wa,country_wa,excountry_wa,gender_wa, sort_wa, check_wa, print_wa]

interactive_actors = interactive_output(actors, {'Top':top_wa,'Year':year_wa,'Country':country_wa,'ExCountry':excountry_wa,'Gender':gender_wa,'Ascending':check_wa,'Sort':sort_wa,'Print':print_wa})
interactive_actors.layout.height = '350px'

ui_actors = widgets.GridBox(wsa, layout=widgets.Layout(grid_template_columns="repeat(2, 400px)"))

display(ui_actors, interactive_actors)
# Out:
# GridBox(children=(IntSlider(value=30, continuous_update=False, description='Results:', layout=Layout(width='35…
# Output(layout=Layout(height='350px'))
